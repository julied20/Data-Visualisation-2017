# %%
# Plot figures in the notebook (instead of a new window)
# %matplotlib notebook

# Automatically reload modules
# %load_ext autoreload
# %autoreload 2        

# The usual imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("datasets", "france_cheese_world.csv"))
df.columns
# Out:
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
#        'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
#        'Mode of Transport', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
#        'Netweight (kg)', 'Gross weight (kg)', 'Trade Value (US$)',
#        'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'],
#       dtype='object')

# %%
df
# Out:
#                                       Classification  Year  Period  \
# 0  No data matches your query or your query is to...   NaN     NaN
#
#    Period Desc.  Aggregate Level  Is Leaf Code  Trade Flow Code  Trade Flow  \
# 0           NaN              NaN           NaN              NaN         NaN
#
#    Reporter Code  Reporter  ...   Qty  Alt Qty Unit Code  Alt Qty Unit  \
# 0            NaN       NaN  ...   NaN                NaN           NaN
#
#    Alt Qty  Netweight (kg)  Gross weight (kg)  Trade Value (US$)  \
# 0      NaN             NaN                NaN                NaN
#
#    CIF Trade Value (US$)  FOB Trade Value (US$)  Flag
# 0                    NaN                    NaN   NaN
#
# [1 rows x 35 columns]

# %%
select_columns = ['Year', 'Netweight (kg)', 'Trade Value (US$)', 'Commodity']
columns_pretty = ['Year', 'Weight', 'Value', 'Commodity']

df_select = df[select_columns].sort_values('Year')
df_select.columns = columns_pretty
df_select
# Out:
#    Year  Weight  Value  Commodity
# 0   NaN     NaN    NaN        NaN

# %%
df_select.plot(x='Year', y=['Value', 'Weight'], kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Chosen years: 1999, 2003, 2007, 2013, 2015**
